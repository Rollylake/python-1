# %%
print("test")
# Out:
# test

# %%
1+1
# Out:
# 2

# %%
print (1+1)
10**3
# Out:
# 2
# 1000

# %%
50 > 25
# Out:
# True

# %%
20 == 20
# Out:
# True

# %%
-15 >= 14.99
# Out:
# False

# %%
print ("it is Tuesday")
# Out:
# it is Tuesday

# %%
type (42)
# Out:
# int

# %%
round (-2 * 1.5)
print (abs (round (-2 * 1.5)
# Out:
# 3

# %%
round (3.5555555,3)
# Out:
# 3.556

# %%
round (2/3)
# Out:
# 1
